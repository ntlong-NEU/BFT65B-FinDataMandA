# %% [markdown]
# ### Lesson 1: Getting started with vs code and jupyter notebook

# %%
print('Hello BFT65B')
# Out:
# Hello BFT65B

# %% [markdown]
# # a
# ## aa
# ### aaa
# #### aaaa
# ##### aaaaa
# ###### aaaaaa
# 1. item
# 2. item
# 3. ite

# %% [markdown]
# - item
# + item

# %% [markdown]
# - **item**

# %% [markdown]
# - *item*

# %% [markdown]
# Đây là `print("Hello World")` trong Python.

# %% [markdown]
# <code>
# print()
# <code>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $x^2 +2x+1 =0$
